# %%
from langchain_openai import ChatOpenAI
import getpass

# %%
OPENAI_API_KEY = getpass.getpass("Enter your OPENAI_API_KEY")
# Out:
# Enter your OPENAI_API_KEY ········

# %%
llm = ChatOpenAI(openai_api_key=OPENAI_API_KEY, model_name="gpt-5-nano")
llm.invoke("It's a hot day, I would like to go to the…")
# Out:
# AIMessage(content='Nice plan. Do you want indoor or outdoor options, and roughly how much time you have? Here are some ideas to beat the heat:\n\nIndoor (cool and quick)\n- Movie theater or cinema\n- Museum or art gallery\n- Library or bookstore cafe\n- Mall or shopping center\n- Indoor pool or gym\n- Aquarium or science museum\n- Coffee shop or bakery with good AC\n\nOutdoor (great if you go early or late)\n- Beach, lake, or splash pad for a quick dip\n- Poolside or water-park visit\n- Shaded park walk or nature trail (bring plenty of water)\n- Botanical garden with mist/streams and shade\n\nTips to stay cool\n- Hydrate and carry water\n- Wear light, loose clothing and a hat\n- Use sunscreen and seek shade when outdoors\n- Plan for early morning or late afternoon to avoid peak sun\n\nIf you tell me your city or what you’re in the mood for (chill indoors vs. active outdoors), I can tailor a specific spot or route.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 924, 'prompt_tokens': 19, 'total_tokens': 943, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 704, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DtfRQY7M6jrk2FMZKiHO6daAmyHLp', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019ef0ff-1907-7fe2-a7ff-dccc475e73ee-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 19, 'output_tokens': 924, 'total_tokens': 943, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 704}})

# %%
prompt_input = """Write a short message to remind users to be
vigilant about phishing attacks."""
response = llm.invoke(prompt_input)
print(response.content)
# Out:
# Stay vigilant against phishing: don’t click unexpected links or open unknown attachments, verify the sender, hover over links to check the URL, and report any suspicious messages to IT.
